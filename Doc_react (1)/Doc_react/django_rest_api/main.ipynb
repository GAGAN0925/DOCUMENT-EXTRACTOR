# %%
import pandas as pd
import os

# %%
documents_df = pd.read_csv('Data\Data Collection.csv')

output_folder = 'extracted_data/'
os.makedirs(output_folder, exist_ok=True)

# %%
from main import process_files,process_pdf_annie

# %%
resultdf = process_files(documents_df,output_folder)

# %%
resultdf.head(20)

# %%
print(resultdf.loc[10,"ocr_text"])

# %%
import cv2
image = cv2.imread("annie_extracted_data\\1706.03762v7\Figure\page_3instance0.jpg")
image = image[..., ::-1]

# %%
import layoutparser as lp
model = lp.Detectron2LayoutModel(
        'lp://PubLayNet/mask_rcnn_X_101_32x8d_FPN_3x/config',
        extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.4],
        label_map={0: "Text", 1: "Title", 2: "List", 3: "Table", 4: "Figure", 5: "Image", 6: "Chart"}  # Added Chart
        #label_map={4: "Figure"}
    )
# Out:
# [10/07 21:45:18 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from C:\Users\Admin/.torch/iopath_cache\s/57zjbwv6gh3srry\model_final.pth ...
# ...

# %%
layout = model.detect(image)
lp.draw_box(image, layout,)
# Out:
# <PIL.Image.Image image mode=RGB size=264x355>

# %%
output_folder = 'annie_extracted_data/'
os.makedirs(output_folder, exist_ok=True)

# %%
resultdf = process_pdf_annie(documents_df,output_folder)
# Out:
# [10/07 21:37:56 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from py_client/model/model.pth ...
# ...

# %%
resultdf
# Out:
#                                        source  \
# 0   https://etheses.dur.ac.uk/1346/1/1346.pdf
# 1   https://etheses.dur.ac.uk/1346/1/1346.pdf
# 2   https://etheses.dur.ac.uk/1346/1/1346.pdf
# 3   https://etheses.dur.ac.uk/1346/1/1346.pdf
# 4   https://etheses.dur.ac.uk/1346/1/1346.pdf
# 5   https://etheses.dur.ac.uk/1346/1/1346.pdf
# 6   https://etheses.dur.ac.uk/1346/1/1346.pdf
# 7   https://etheses.dur.ac.uk/1346/1/1346.pdf
# 8   https://etheses.dur.ac.uk/1346/1/1346.pdf
# 9   https://etheses.dur.ac.uk/1346/1/1346.pdf
# 10  https://etheses.dur.ac.uk/1346/1/1346.pdf
# 11  https://etheses.dur.ac.uk/1346/1/1346.pdf
# 12  https://etheses.dur.ac.uk/1346/1/1346.pdf
# 13  https://etheses.dur.ac.uk/1346/1/1346.pdf
# 14  https://etheses.dur.ac.uk/1346/1/1346.pdf
# 15  https://etheses.dur.ac.uk/1346/1/1346.pdf
# 16  https://etheses.dur.ac.uk/1346/1/1346.pdf
# 17  https://etheses.dur.ac.uk/1346/1/1346.pdf
# 18  https://etheses.dur.ac.uk/1346/1/1346.pdf
# ...

# %%
resultdf.iloc[6,5]
# Out:
# 'annie_extracted_data/1706.03762v7/Figure\\page_3instance0.jpg'

# %%
resultdf.to_csv("alexandra the great.csv", index=False)
